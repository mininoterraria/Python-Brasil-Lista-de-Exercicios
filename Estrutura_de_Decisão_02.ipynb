# %%
#01) Faça um Programa que peça dois números e imprima o maior deles.

numero_01 = int(input("Insira o primeiro número: "))
numero_02 = int(input("Insira o segundo número: "))

#Estrutura de decisão para ver qual número é maior.
if(numero_01 > numero_02):
  print("Número 1 é maior que Número 2.")
  print(numero_01)
elif(numero_02 > numero_01):
  print("Número 2 é maior que Número 1.")
  print(numero_02)
else:
  print("Os números são iguais.")

# %%
#02) Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

valor = int(input("Insira um valor qualquer: "))

#Estrutura de decisão para decidir se o valor digitado é positivo ou negativo.
if(valor >= 0):
  print("Esse valor é positivo.")
else:
  print("Esse valor é negativo.")

# %%
#03) Faça um Programa que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, Sexo Inválido.

letra = input("Insira F ou M: ").upper()

#Estrutura de decisão para decidir se o sexo é masculino, feminino, ou inválido.
if(letra == 'F'):
  print("F - Feminino.")
elif(letra == 'M'):
  print("M - Masculino.")
else:
  print("Sexo Inválido.")

# %%
#04) Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

#Lista de vogais e consoantes.
vogais = ['A','E','I','O','U']
consoantes= ['B', 'C', 'D', 'F', 'G', 'H', 'J', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'X', 'Y', 'Z']

letra = input("Insira uma letra qualquer: ").upper()

#Estrutura de decisão para definir se a letra inserida é vogal, consoante ou inválida.
if(letra in vogais):
  print("É vogal.")
elif(letra in consoantes):
  print("É consoante.")
else:
  print("Letra Inválida.")

# %%
#05) Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar
    #A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
    #A mensagem "Reprovado", se a média for menor do que sete;
    #A mensagem "Aprovado com Distinção", se a média for igual a dez.

nota_01 = float(input("Insira a primeira nota: "))
nota_02 = float(input("Insira a segunda nota: "))

#Caso uma das notas seja menor ou maior que 10, será dado como inválido, não executando o restante do código.
if(nota_01 > 10 or nota_01 < 0 or nota_02 > 10 or nota_02 < 0):
  print("Uma ou mais notas inválidas!")
else:
  #Cálculo para fazer a média das notas.
  media = (nota_01 + nota_02) / 2
  print(f"Média do aluno: {media}")

  #Estrutura de decisão para definir se o aluno foi aprovado, reprovado ou aprovado com distinção.
  if(media >= 7 and media < 10):
    print("Aprovado.")
  elif(media < 7):
    print("Reprovado.")
  else:
    print("Aprovado com distinção!")

# %%
#06) Faça um Programa que leia três números e mostre o maior deles.

num1 = int(input("Insira o primeiro número: "))
num2 = int(input("Insira o segundo número: "))
num3 = int(input("Insira o terceiro número: "))

#Variável que definirá o ponto de partida para decidir o maior valor.
maior = num1

#Estrutura de decisão para definir qual o maior número.
if(num2 > maior):
  maior = num2
elif(num3 > maior):
  maior = num3
print(f"O maior valor é: {maior}")

# %%
#07) Faça um Programa que leia três números e mostre o maior e o menor deles.

num1 = int(input("Insira o primeiro número: "))
num2 = int(input("Insira o segundo número: "))
num3 = int(input("Insira o terceiro número: "))

#Variáveis que são usadas de ponto de partida para definir o maior e o menor valor.
maior = num1
menor = num1

#Estrutura de decisão para definir qual o maior número.
if(num2 > maior):
  maior = num2
elif(num2 < menor):
  menor = num2

if(num3 > maior):
  maior = num3
elif(num3 < menor):
  menor = num3

print(f"O maior valor é: {maior}")
print(f"O menor valor é: {menor}")

# %%
#08) Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

produto_1 = float(input("Informe o preço do produto 1: "))
produto_2 = float(input("Informe o preço do produto 2: "))
produto_3 = float(input('Informe o preço do produto 3: '))

#Variáveis que seram utilizadas como ponto de partida para definir o produto mais barato e o nome do produto respectivamente.
mais_barato = produto_1
nome_produto = 'Produto 1'

#Estrutura de decisão que para definir o produto mais barato.
if(produto_2 < mais_barato):
  mais_barato = produto_2
  nome_produto = 'Produto 2'

if(produto_3 < mais_barato):
  mais_barato = produto_3
  nome_produto = 'Produto 3'

print(f"O produto mais barato é o {nome_produto}")

# %%
#09) Faça um Programa que leia três números e mostre-os em ordem decrescente.

numero_1 = int(input("Insira o primeiro número: "))
numero_2 = int(input("Insira o segundo número: "))
numero_3 = int(input('Insira o terceiro número: '))

#Variáveis que serão utilizadas para definir os valores: maior, meio e menor respectivamente.
maior = numero_1
menor = numero_1
meio = numero_1

#Estrutura de decisão para definir o maior valor.
if(numero_2 > maior):
  maior = numero_2
if(numero_3 > maior):
  maior = numero_3
#Estrutura de decisão para definir o menor valor.
if(numero_2 < menor):
  menor = numero_2
if(numero_3 < menor):
  menor = numero_3

#Estrutura de decisão para definir o valor do meio em todas as possiveis situações.
if(maior == numero_1 and menor == numero_2):
  meio = numero_3
elif(maior == numero_2 and menor == numero_1):
  meio = numero_3

elif(maior == numero_1 and menor == numero_3):
  meio = numero_2
elif(maior == numero_3 and menor == numero_1):
  meio = numero_2

elif(maior == numero_2 and menor == numero_3):
  meio = numero_1
elif(maior == numero_3 and menor == numero_2):
  meio = numero_1

print(f"Ordem: {maior},{meio},{menor}")

# %%
#10) Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

#Lista de turnos válidos.
turnos_validos = ['M','V','N']

turno = input("Em que turno você estuda? R:").upper()

#Estrutura de decisão que exibirá o turno correto ou valor inválido de acordo com o dígito do usuário.
if(turno in turnos_validos):
  if(turno == 'M'):
    print("Bom Dia!")
  elif(turno == 'V'):
    print("Boa Tarde!")
  elif(turno == 'N'):
    print("Boa Noite!")
else:  print("Valor Inválido!")

# %%
"""
#11) As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
salários até R$ 280,00 (incluindo) : aumento de 20%
salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
o salário antes do reajuste;
o percentual de aumento aplicado;
o valor do aumento;
o novo salário, após o aumento.

"""

salario = float(input("Insira o salário: "))

#Variável do percentual de aumento que variará de acordo com o input do usuário.
percentual_aumento = 0

#Caso o salario seja menor ou igual a 0, retornará valor inválido, não executando o restante do código.
if(salario <= 0):
  print("Valor inválido!")
else:
  #Estrutura de decisão que fará os devidos cálculos do novo salário, de acordo com o input do usuário.
  if(salario <= 280):
    percentual_aumento = 0.20
    aumento = salario * percentual_aumento
    novo_salario = salario + aumento
  elif(salario > 280 and salario <= 700):
    percentual_aumento = 0.15
    aumento = salario * percentual_aumento
    novo_salario = salario + aumento
  elif(salario > 700 and salario <= 1500):
    percentual_aumento = 0.10
    aumento = salario * percentual_aumento
    novo_salario = salario + aumento
  else:
    percentual_aumento = 0.05
    aumento = salario * percentual_aumento
    novo_salario = salario + aumento

  print(f"Salário antes do reajuste: R$ {salario}")
  print(f"Percentual do aumento aplicado: {percentual_aumento * 100:.2f}%")
  print(f"Valor do aumento: R$ {aumento}")
  print(f"Novo salário após o aumento: R$ {novo_salario}")

# %%
"""
#12) Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.
Desconto do IR:
Salário Bruto até 900 (inclusive) - isento
Salário Bruto até 1500 (inclusive) - desconto de 5%
Salário Bruto até 2500 (inclusive) - desconto de 10%
Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220.
"""

hora_por_dia = int(input("Insira a quantidade de horas trabalhadas: "))
horas_mes = int(input("Insira a quantidade de horas trabalhadas no mês: "))

#Se a hora por dia ou mês for menor ou igual a 0, dará como valor inválido, não realizando o cálculo.
if(hora_por_dia <= 0 or horas_mes <= 0):
  print("Um ou mais valores inválidos!")
else:
  #Cálculo do salário bruto.
  salario_bruto = hora_por_dia * horas_mes

  #Descontos
  sindicato = salario_bruto * 0.03
  inss = salario_bruto * 0.10
  fgts = salario_bruto * 0.11 #Esse desconto é a empresa que paga, não será descontado do salário bruto do usuário.

  #Estrutura de decisão para definir o desconto de imposto de renda de acordo com o input do usuário.
  if(salario_bruto <= 900):
    imposto_renda = 'Isento'
    frase_imposto_renda = f'(-) IR: {imposto_renda:.2f}'
  elif(salario_bruto > 900 and salario_bruto <= 1500):
    imposto_renda = salario_bruto * 0.05
    frase_imposto_renda = f'(-) IR (5%): {imposto_renda:.2f}'
  elif(salario_bruto > 1500 and salario_bruto <= 2500):
    imposto_renda = salario_bruto * 0.10
    frase_imposto_renda = f'(-) IR (10%): {imposto_renda:.2}'
  else:
    imposto_renda = salario_bruto * 0.20
    frase_imposto_renda = f'(-) IR (20%): {imposto_renda:.2f}'

  #Estrutura de decisão que fará a soma de todos os descontos de acordo com o valor do salário bruto.
  if(salario_bruto <= 900):
    total_descontos = sindicato + inss
  else:
    total_descontos = sindicato + inss + imposto_renda

  #Estrutura de decisão que fará o cálculo do salário líquido e exibirá a devida frase referente ao imposto de renda de acordo com o salário bruto.
  if(salario_bruto <= 900):
    salario_liquido = salario_bruto - (sindicato + inss)
  else:
    salario_liquido = salario_bruto - (sindicato + inss + imposto_renda)

  print(f"Salário Bruto: R$ {salario_bruto:.2f}")
  print(f"(-) Sindicato (3%): R$ {sindicato:.2f}")
  print(f"(-) INSS (10%): R$ {inss:.2f}")
  print(f"FGTS (11%): R${fgts:.2f} (DEPOSITADO PELA EMPRESA)")
  print(f"{frase_imposto_renda}")
  print(f"Total de descontos: R${total_descontos:.2f}")
  print(f"Salário Líquido: R$ {salario_liquido:.2f}")

# %%
#13) Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

digito_dia = int(input("Insira o número referente ao dia: "))

#Se o digito for menor ou igual a 0 ou maior que 7, exibirá valor inválido.
if(digito_dia <= 0 or digito_dia > 7):
  print("Dígito Inválido!")
else:
  #Estrutura de decisão para definir o dia de acordo com o dígito do usuário.
  if(digito_dia == 1):
    print("1-Domingo")
  elif(digito_dia == 2):
    print("2-Segunda")
  elif(digito_dia == 3):
    print("3-Terça")
  elif(digito_dia == 4):
    print("4-Quarta")
  elif(digito_dia == 5):
    print("5-Quinta")
  elif(digito_dia == 6):
    print("6-Sexta")
  else:
    print("7-Sábado")

# %%
"""
#14) Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. A atribuição de conceitos obedece à tabela abaixo:
  Média de Aproveitamento  Conceito
  Entre 9.0 e 10.0        A
  Entre 7.5 e 9.0         B
  Entre 6.0 e 7.5         C
  Entre 4.0 e 6.0         D
  Entre 4.0 e zero        E
O algoritmo deve mostrar na tela as notas, a média, o conceito correspondente e a mensagem “APROVADO” se o conceito for A, B ou C ou “REPROVADO” se o conceito for D ou E.
"""

nota1 = float(input("Insira a nota 1: "))
nota2 = float(input("Insira a nota 2: "))

#Caso uma das notas seja menor que 0 ou maior que 10, será dado como inválido.
if(nota1 < 0 or nota1 > 10 or nota2 < 0 or nota2 > 10):
  print("Um ou mais valores inválidos!")
else:
  media = (nota1 + nota2) / 2 #Cálculo da média
  print(f"Média: {media}")  #Exibição da média

  #Estrutura de decisão para decidir se o usuário está aprovado ou reprovado de acordo com os conceitos.
  if(media >= 0 and media < 4):
    print("CONCEITO E")
    print("REPROVADO")
  elif(media >= 4 and media < 6):
    print("CONCEITO D")
    print("REPROVADO")
  elif(media >= 6 and media < 7.5):
    print("CONCEITO C")
    print("APROVADO")
  elif(media >= 7.5 and media < 9.0):
    print("CONCEITO B")
    print("APROVADO")
  else:
    print("CONCEITO A")
    print("APROVADO")

# %%
"""
#15) Faça um Programa que peça os 3 lados de um triângulo. O programa deverá informar se os valores podem ser um triângulo. Indique, caso os lados formem um triângulo, se o mesmo é: equilátero, isósceles ou escaleno.
Dicas:
Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
Triângulo Equilátero: três lados iguais;
Triângulo Isósceles: quaisquer dois lados iguais;
Triângulo Escaleno: três lados diferentes;
"""

lado1 = float(input("Informe o primeiro lado: "))
lado2 = float(input("Informe o segundo lado: "))
lado3 = float(input("Informe o terceiro lado: "))

#Caso um dos lados tiver medida menor ou igual a 0, será dado como inválido!
if(lado1 <= 0 or lado2 <= 0 or lado3 <= 0):
  print("Uma ou mais medidas inválidas!")
else:
  #Caso nenhuma das medidas da soma de dois lados seja menor que o terceiro, informará que essas medidas não formam um triângulo
  if((lado1 + lado2) > lado3 and (lado1 + lado3) > lado2 and (lado2 + lado3) > lado1):

    #Estrutura de decisão para definir o tipo de triângulo de acordo com as medidas.
    if(lado1 == lado2 and lado1 == lado3 and lado2 == lado3):
      print("Isso é um triângulo equilátero.")
    elif(lado1 == lado2 or lado1 == lado3 or lado2 == lado3):
      print("Isso é um triângulo isósceles.")
    elif(lado1 != lado2 and lado1 != lado3 and lado2 != lado3):
       print("Isso é um triângulo escaleno.")

  else:
    print("Essas medidas não formam um triângulo!")

# %%
"""
#16) Faça um programa que calcule as raízes de uma equação do segundo grau, na forma ax2 + bx + c. O programa deverá pedir os valores de a, b e c e fazer as consistências, informando ao usuário nas seguintes situações:
Se o usuário informar o valor de A igual a zero, a equação não é do segundo grau e o programa não deve fazer pedir os demais valores, sendo encerrado;
Se o delta calculado for negativo, a equação não possui raizes reais. Informe ao usuário e encerre o programa;
Se o delta calculado for igual a zero a equação possui apenas uma raiz real; informe-a ao usuário;
Se o delta for positivo, a equação possui duas raiz reais; informe-as ao usuário;
"""

a = float(input("Insira o valor de A: "))
if(a == 0): #Caso A seja igual a 0, a equação não será do segundo grau, encerrado o restante do código e não pedindo os demais valores.
  print("A equação não é do segundo grau, programa encerrado.")
else:
  b = float(input("Insira o valor de B: "))
  c = float(input("Insira o valor de C: "))

  delta = (b * b) - (4 * a * c) #Cálculo do delta
  print(f"Delta: {delta:.2f}")

  #Estrutura de decisão para exibir os devidos resultados de acordo com o valor do delta.
  if(delta < 0):
    print("A equação não possui raizes reais, programa encerrado.")
  elif(delta == 0):
    print("A equação possui uma raiz real.")
    raiz_unica = -b / (2 * a)
    print(f"Raiz única: {raiz_unica:.2f}")
  else:
    print("O delta possui duas raizes reais.")
    raiz1 = (-b + (delta ** 0.5) ) / (2 * a)
    raiz2 = (-b - (delta ** 0.5)) / (2 * a)
    print(f"Raiz 1: {raiz1:.2f}")
    print(f"Raiz 2: {raiz2:.2f}")

# %%
#17) Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.
ano = int(input("Insira um ano: "))

#Estrutura de decisão para definir o ano bissexto
if(ano % 4 == 0 and ano % 100 == 0 and ano % 400 == 0): #Divisivel por 4, por 100 e por 400, é bissexto.
  print("É bissexto.")
elif(ano % 4 == 0 and ano % 100 == 0 and not ano % 400 == 0): #Divisivel por 4, por 100 e não por 400, não é bissexto.
  print("Não é bissexto.")
elif(ano % 4 == 0): #Divisivel apenas por 4, é bissexto.
  print("É bissexto.")
else:
  print("Não é bissexto.") #Caso nenhuma das opções acimas de bissexto sejam atendidas, não é bissexto.

# %%
#18)Faça um Programa que peça uma data no formato dd/mm/aaaa e determine se a mesma é uma data válida.

dia = int(input("Insira o dia: "))
mes = int(input("Insira o mês: "))
ano = int(input("Insira o ano: "))

meses_31_dias = [1,3,5,7,8,10,12] #Meses com 31 dias
meses_30_dias = [4,6,9,11] #Meses com 30 dias

flag = 0 #Essa variável será utilizada para exibir a data caso não tenha nenhuma invalidade.

#Parte da estrutura de decisão para validação do dia.
if(dia <= 0):
  print("Dia não pode ser menor ou igual a 0!")
  flag += 1
if(dia > 31):
  print("Dia não pode ultrapassar 31!")
  flag += 1
if(dia == 31 and mes in meses_30_dias):
  print("Não há dia 31 para esse mês!")
  flag += 1
if(dia > 29 and mes == 2):
  print("Fevereiro não tem mais de 29 dias!")
  flag += 1
#Parte da estrutura de decisão para validação do mês
if(mes <= 0):
  print("Mês não pode ser menor ou igual a 0!")
  flag += 1
if(mes > 12):
  print("Mês não pode ultrapassar 12!")
  flag += 1
#Parte da estrutura de decisão para validação do ano
if(ano <= 0):
  print("Ano não pode ser menor ou igual a 0!")
  flag += 1

#Estrutura de decisão para definir o ano bissexto
if(dia == 29 and mes == 2):
  if(ano % 4 == 0 and ano % 100 == 0 and ano % 400 == 0): #Divisivel por 4, por 100 e por 400, é bissexto.
    pass #Não faz nada, apenas pula pro próximo código
  elif(ano % 4 == 0 and ano % 100 == 0 and not ano % 400 == 0): #Divisivel por 4, por 100 e não por 400, não é bissexto.
    print("Fevereiro não tem 29 dias em ano não bissexto!")
    flag += 1
  elif(ano % 4 == 0): #Divisivel apenas por 4, é bissexto.
    pass #Não faz nada, apenas pula pro próximo código
  else: #Caso nenhuma das opções acimas de bissexto sejam atendidas, não é bissexto.
    print("Fevereiro não tem 29 dias em ano não bissexto!")
    flag += 1

#A data só será valida caso não tenha nenhum incremento na flag.
if(flag == 0):
  print(f"{dia}/{mes}/{ano}")

# %%
"""
19) Faça um Programa que leia um número inteiro menor que 1000 e imprima a quantidade de centenas, dezenas e unidades do mesmo.
Observando os termos no plural a colocação do "e", da vírgula entre outros. Exemplo:
326 = 3 centenas, 2 dezenas e 6 unidades
12 = 1 dezena e 2 unidades Testar com: 326, 300, 100, 320, 310,305, 301, 101, 311, 111, 25, 20, 10, 21, 11, 1, 7 e 16
"""
numero = int(input("Insira um número inteiro menor que 1000:"))

#Variáveis que serão utilizadas para colocar o nome em plural ou singular de acordo com o número.
unidade = ''
dezena = ''
centena = ''

dezenas_unicas = [10,20,30,40,50,60,70,80,90] #Lista de dezenas que fecham 0.
centenas_unicas = [100,200,300,400,500,600,700,800,900] #Lista de centenas que fecham 0.

#Caso o número seja menor ou igual a 0 ou maior igual a 1000, será dado como inválido.
if(numero <= 0):
  print("Número não pode ser menor ou igual a 0.")
elif(numero >= 1000):
  print("Número não pode ser maior ou igual a 1000.")
else:

  if(numero >= 0 and numero <= 9): #Estrutura de decisão para números entre 1 à 9.
    if(numero == 1):
      unidade = 'unidade'
    else:
      unidade = 'unidades'
    print(f"{numero} {unidade}")

  elif(numero in dezenas_unicas): #Estrutura de decisão para os valores das dezenas únicas.
    numero = str(numero)
    if(numero[-2] == '1'):
      dezena = 'dezena'
    else:
      dezena = 'dezenas'
    print(f"{numero[-2]} {dezena}")

  elif(numero > 10 and numero <= 99): #Estrutura de decisão para os valores entre 11 à 99, excluindo as dezenas únicas.
    numero = str(numero)
    if(numero[-2] == '1'):
      dezena = 'dezena'
    else:
      dezena = 'dezenas'
    if(numero[-1] == '1'):
      unidade = 'unidade'
    else:
      unidade = 'unidades'
    print(f"{numero[-2]} {dezena} e {numero[-1]} {unidade}")

  elif(numero in centenas_unicas): #Estrutura de decisão para os valores das centenas únicas.
    numero = str(numero)
    if(numero[-3] == '1'):
      centena = 'centena'
    else:
      centena = 'centenas'
    print(f"{numero[-3]} {centena}")

  elif(numero > 100): #Estrutura de decisão para valores acima de 100, excluindo as centenas únicas.
    numero = str(numero)

    if(numero[-3] == '1'):
      centena = 'centena'
    else:
      centena = 'centenas'

    if(numero[-2] == '1'):
      dezena = 'dezena'
    else:
      dezena = 'dezenas'

    if(numero[-1] == '1'):
      unidade = 'unidade'
    else:
      unidade = 'unidades'

    if(numero[-2] == '0' and numero[-1] != '0'):
      print(f"{numero[-3]} {centena} e {numero[-1]} {unidade}")
    elif(numero[-2] != '0' and numero[-1] == '0'):
      print(f"{numero[-3]} {centena} e {numero[-2]} {dezena}")
    else:
      print(f"{numero[-3]} {centena}, {numero[-2]} {dezena} e {numero[-1]} {unidade}")

# %%
"""
20) Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e presentar:
A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;
A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;
A mensagem "Aprovado com Distinção", se a média for igual a 10.

"""

nota_1 = float(input("Insira a nota 1: "))
nota_2 = float(input("Insira a nota 2: "))
nota_3 = float(input("Insira a nota 3:"))

#Caso qualquer uma das notas seja menor que 0 ou superior à 10, será dado como inválido, não executando o restante do código.
if(nota_1 < 0 or nota_1 > 10 or nota_2 < 0 or nota_2 > 10 or nota_3 < 0 or nota_3 > 10):
  print("Um ou mais valores inválidos!")
else:

  media = (nota_1 + nota_2 + nota_3) / 3  #Cálculo da média

  #Estrutura de decisão para validar a média.
  if(media == 10):
    print("Aprovado com distinção!")
  elif(media < 10 and media >= 7):
    print("Aprovado!")
  else:
    print("Reprovado!")

  print(f"Média do aluno: {media:.2f}")

# %%
"""
#21) Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário a valor do saque e depois
informar quantas notas de cada valor serão fornecidas. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e
o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.
Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1
"""

saque = int(input("Insira o valor do saque: "))

#Variáveis que serão utilizadas para o nome nota no singular / plural.
nome_nota100 = ''
nome_nota50 = ''
nome_nota10 = ''
nome_nota5 = ''
nome_nota1 = ''

#Caso o valor do saque seja inferior a 10 ou superior a 600, dará como inválido, não executando o restante do código.
if(saque < 10 or saque > 600):
  print("O valor mínimo é 10 reais, e o máximo 600 reais.")
else:
      #Cálculo para definir a quantidade de cada tipo de nota.
      notas_100 = saque // 100
      resto_100 = saque % 100

      notas_50 = resto_100 // 50
      resto_50 = resto_100 % 50

      notas_10 = resto_50 // 10
      resto_10 = resto_50 % 10

      notas_5 = resto_10 // 5
      resto_5 = resto_10 % 5

      notas_1 = resto_5 // 1
      resto_1 = resto_5 % 1


      #Estrutura de decisão para nota ser plural ou singular.
      if(notas_100 == 1):
        nome_nota100 = 'nota'
      else:
        nome_nota100 = 'notas'

      if(notas_50 == 1):
        nome_nota50 = 'nota'
      else:
        nome_nota50 = 'notas'

      if(notas_10 == 1):
        nome_nota10 = 'nota'
      else:
        nome_nota10 = 'notas'

      if(notas_5 == 1):
        nome_nota5 = 'nota'
      else:
        nome_nota5 = 'notas'

      if(notas_1 == 1):
        nome_nota1 = 'nota'
      else:
        nome_nota1 = 'notas'

      #Estrutura de decisão para exibir quantas notas serão dadas.
      print("Serão dadas:")

      if(notas_100 > 0):
        print(f"{notas_100} {nome_nota100} de 100 reais.")

      if(notas_50 > 0):
        print(f"{notas_50} {nome_nota50} de 50 reais.")

      if(notas_10 > 0):
        print(f"{notas_10} {nome_nota10} de 10 reais.")

      if(notas_5 > 0):
        print(f"{notas_5} {nome_nota5} de 5 reais.")

      if(notas_1 > 0):
        print(f"{notas_1} {nome_nota1} de 1 real.")

# %%
#22) Faça um Programa que peça um número inteiro e determine se ele é par ou impar. Dica: utilize o operador módulo (resto da divisão).

numero = int(input("Insira um número: "))

#Estrutura de decisão para definir se o número é par ou impar.
if(numero % 2 == 0):
  print("É par.")
else:
  print("É impar.")

# %%
#23) Faça um Programa que peça um número e informe se o número é inteiro ou decimal. Dica: utilize uma função de arredondamento

numero = float(input("Insira um número: "))

#Estrutura de decisão para definir se o número é inteiro ou decimal, usando a função de arredondamento round().
if(numero == round(numero)):
  print("É inteiro")
else:
  print("É decimal.")

# %%
"""
#24) Faça um Programa que leia 2 números e em seguida pergunte ao usuário qual operação ele deseja realizar. O resultado da operação deve ser acompanhado de uma frase que diga se o número é:
par ou ímpar;
positivo ou negativo;
inteiro ou decimal.
"""

#Operações válidas.
operacoes = ['+','-','*','/']

numero_1 = float(input("Insira um número: "))
numero_2 = float(input("Insira outro número: "))
operacao = input("Insira o símbolo da operação desejada (+) | (-) | (*) | (/):")

resultado = 0 #Variável que ficará armazenado o resultado da operação.

#Caso a operação dada pelo usuário seja diferente das tradicionais, será dado como inválido, não executando o restante do código.
if(operacao not in operacoes):
  print("Operação inválida!")
else:

  #Estrutura de decisão para fazer a devida operação.
  if(operacao == '+'):
    resultado = (numero_1 + numero_2)
  elif(operacao == '-'):
    resultado = (numero_1 - numero_2)
  elif(operacao == '*'):
    resultado = (numero_1 * numero_2)
  elif(operacao == '/'):
    resultado = (numero_1 / numero_2)

  print(f"Resultado: {resultado}") #Exibe o valor da operação

  #Estrutura de decisão para definir se é par ou impar.
  if(resultado % 2 == 0):
    print("É par.")
  else:
    print("É impar.")

  #Estrutura de decisão para definir se é negativo ou positivo.
  if(resultado < 0):
    print("É negativo.")
  else:
    print("É positivo.")

  #Estrutura de decisão para definir se é inteiro ou decimal.
  if(resultado == round(resultado)):
    print("É inteiro")
  else:
    print("É decimal.")

# %%
"""
#25) Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
"Telefonou para a vítima?"
"Esteve no local do crime?"
"Mora perto da vítima?"
"Devia para a vítima?"
"Já trabalhou com a vítima?" O programa deve no final emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice" e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".
"""


#Respostas válidas.
resposta_valida = ['sim','SIM','Sim','s','não','nao','NÃO','NAO','Não','Nao','n']

pergunta_1 = input("Telefonou para a vítima?: ")
pergunta_2 = input("Esteve no local do crime?: ")
pergunta_3 = input("Mora perto da vítima?: ")
pergunta_4 = input("Devia para a vítima?: ")
pergunta_5 = input("Já trabalhou com vítima?: ")

#Caso uma das respostas das perguntas seja diferente das respostas válidas, será dado como inválido, não executando o restante do código.
if(pergunta_1 not in resposta_valida or pergunta_2 not in resposta_valida or pergunta_3 not in resposta_valida or pergunta_4 not in resposta_valida or pergunta_5 not in resposta_valida):
  print("Uma ou mais respostas inválidas!")
else:

    contador = 0 #Variável que acumulará a quantidade de respostas positivas.

    #Estrutura de decisão para contabilizar as respostas positivas de cada pergunta.
    if(pergunta_1 == 'sim' or pergunta_1 == 'SIM' or pergunta_1 == 'Sim' or pergunta_1 == 's'):
      contador += 1
    if(pergunta_2 == 'sim' or pergunta_2 == 'SIM' or pergunta_2 == 'Sim' or pergunta_2 == 's'):
      contador += 1
    if(pergunta_3 == 'sim' or pergunta_3 == 'SIM' or pergunta_3 == 'Sim' or pergunta_3 == 's'):
      contador += 1
    if(pergunta_4 == 'sim' or pergunta_4 == 'SIM' or pergunta_4 == 'Sim' or pergunta_4 == 's'):
      contador += 1
    if(pergunta_5 == 'sim' or pergunta_5 == 'SIM' or pergunta_5 == 'Sim' or pergunta_5 == 's'):
      contador += 1

    #Estrutura de decisão para definir a classificação do suspeito de acordo com as perguntas respondidas.
    if(contador == 2):
      print("O entrevistado é suspeito.")
    elif(contador == 3 or contador == 4):
      print("O entrevistado é cúmplice.")
    elif(contador == 5):
      print("O entrevistado é assassino.")
    else:
      print("O entrevistado é inocente.")

# %%
"""
#26) Um posto está vendendo combustíveis com a seguinte tabela de descontos:
Álcool:
até 20 litros, desconto de 3% por litro
acima de 20 litros, desconto de 5% por litro

Gasolina:
até 20 litros, desconto de 4% por litro
acima de 20 litros, desconto de 6% por litro

Escreva um algoritmo que leia o número de litros vendidos, o tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina),
calcule e imprima o valor a ser pago pelo cliente sabendo-se que o preço do litro da gasolina é R$ 2,50 o preço do litro do álcool é R$ 1,90.
"""

#Respostas válidas para escolher o combustivel
respostas_validas = ['g','G','a','A']

litros = float(input("Insira a quantidade de litros: "))
combustivel = input("Insira o tipo de gasolina (A-álcool, G-gasolina): ")

#Variáveis que serão utilizadas para o cálculo do preço.
preco_total = 0
valor_desconto = 0
preco_final = 0

#Caso litros seja menor ou igual a 0 ou o tipo de gasolina seja diferente dos decididos, será dado como inválido, não executando o restante do código.
if(litros <= 0):
  print("Quantidade de litros inválida!")

if(combustivel not in respostas_validas):
  print("Tipo de combustivel inválido!")

#Caso o litro seja maior que 0 e o combustivel seja uma das respostas válidas, executará o código restante.
if(litros > 0 and combustivel in respostas_validas):

    #Estrutura de decisão para até 20 litros ou superior para cada tipo de combustível com os devidos cálculos.
    if(litros <= 20 and (combustivel == 'A' or combustivel == 'a')):

      preco_total = (1.90 * litros)
      desconto_total = (litros * (1.90 * 0.03))
      preco_final = (preco_total - desconto_total)

    elif(litros > 20 and(combustivel == 'A' or combustivel == 'a')):

      preco_total = (1.90 * litros)
      desconto_total = (litros * (1.90 * 0.05))
      preco_final = (preco_total - desconto_total)

    elif(litros <= 20 and (combustivel == 'G' or combustivel == 'g')):

      preco_total = (2.50 * litros)
      desconto_total = (litros * (2.50 * 0.04))
      preco_final = (preco_total - desconto_total)

    elif(litros > 20 and (combustivel == 'G' or combustivel == 'g')):

      preco_total = (2.50 * litros)
      desconto_total = (litros * (2.50 * 0.06))
      preco_final = (preco_total - desconto_total)

    print(f"Valor sem desconto: R${preco_total:.2f} ")
    print(f"Valor do desconto por litro: R${desconto_total:.2f} ")
    print(f"Preço Final: R${preco_final:.2f}")

# %%
"""
#27) Uma fruteira está vendendo frutas com a seguinte tabela de preços:
                      Até 5 Kg           Acima de 5 Kg
Morango         R$ 2,50 por Kg          R$ 2,20 por Kg
Maçã            R$ 1,80 por Kg          R$ 1,50 por Kg
Se o cliente comprar mais de 8 Kg em frutas ou o valor total da compra ultrapassar R$ 25,00, receberá ainda um desconto de 10% sobre este total. Escreva um algoritmo para ler a
quantidade (em Kg) de morangos e a quantidade (em Kg) de maças adquiridas e escreva o valor a ser pago pelo cliente.
"""

morango_kg = float(input("Insira a quantidade de quilos do morango: "))
maca_kg = float(input("Insira a quantidade de quilos da maçã: "))

preco_final_morango = 0 #Variável que será usada no cálculo do preço do morango
preco_final_maca = 0 #Variável que será usada no cálculo do preço da maçã
quilos_total = 0 #Variável que será usada no cálculo do total de quilos.
valor_total = 0 #Variável que será usada no cálculo do preço final.
desconto = 0 #Variável que aplicará o desconto no valor final caso quilos total seja superior a 8 ou o valor da compra total ultrapasse 25 reais.

#Caso o kg do morango ou da maca seja menor ou igual a 0, dará como inválido, não executando o código restante.
if(morango_kg < 0 or maca_kg < 0 or (morango_kg < 0 and maca_kg < 0)):
  print("Um ou mais valores de quilos inválido!")
else:

  #Estrutura de decisão para definir o preço do morango de acordo com o quilo exigido.
  if(morango_kg <= 5):

    preco_final_morango = (morango_kg * 2.50)

  elif(morango_kg > 5):

    preco_final_morango = (morango_kg * 2.20)

  #Estrutura de decisão para definir o preço da maçã de acordo com o quilo exigido.
  if(maca_kg <= 5):

    preco_final_maca = (maca_kg * 1.80)

  elif(maca_kg > 5):

    preco_final_maca = (maca_kg * 1.50)

  quilos_total = (morango_kg + maca_kg)
  valor_total = (preco_final_morango + preco_final_maca)

  #Estrutura de decisão para aplicar ou não o desconto.
  if(quilos_total > 8 or valor_total > 25):

    desconto = (valor_total * 0.10)
    valor_total_com_desconto = (valor_total - desconto)
    print(f"Valor total a pagar (com desconto de 10%): R$ {valor_total_com_desconto:.2f}")

  else:

    print(f"Valor total a pagar: R$ {valor_total:.2f}")

# %%
"""
#28) O Hipermercado Tabajara está com uma promoção de carnes que é imperdível. Confira:
                      Até 5 Kg           Acima de 5 Kg
File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg
Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg
Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg
Para atender a todos os clientes, cada cliente poderá levar apenas um dos tipos de carne da promoção,
porém não há limites para a quantidade de carne por cliente. Se compra for feita no cartão Tabajara o cliente receberá ainda um desconto de 5% sobre o total da compra.
Escreva um programa que peça o tipo e a quantidade de carne comprada pelo usuário e gere um cupom fiscal, contendo as informações da compra: tipo e quantidade de carne, preço total, tipo de pagamento,
 valor do desconto e valor a pagar.
"""

respostas_validas = ['F','f','A','a','P','p'] #Respostas válidas para o tipo de carne
resposta_cartao_valida = ['s','S','N','n'] #Respostas válidas para uso do cartão tabajara.

tipo_carne = input("Insira o tipo de carne para comprar F-file Duplo / A-alcatra / P-picanha: ")
quilos = float(input("Insira a quantidade em quilos: "))
cartao_tabajara = input("Usará o cartão tabajara?: ")

nome_carne = '' #Variável que exibirá o nome da carne no cupom fiscal.
forma_pagamento = 'Dinheiro' #Variável que exibirá a forma de pagamento no cupom fiscal.
preco_final = 0 #Preço final que será usado no cálculo do preço da carne.
desconto = 0 #Desconto que será aplicado caso seja usado o cartão tabajara.


if(tipo_carne not in respostas_validas): #Se a resposta do tipo da carne não for uma das válidas, será dado como inválido, não executando o restante do código
  print("Tipo de carne inválida!")

if(quilos < 0 ): #Se os quilos forem negativos, será dado como inválido, não executando o resto do código.
  print("Quantide em quilos inválido!")

if(cartao_tabajara not in resposta_cartao_valida): #Se a pergunta do uso do cartão não for uma resposta válida, será dado como inválido, não executando o restante do código.
  print("Resposta do cartão inválida!")


if(tipo_carne in respostas_validas and quilos >= 0 and cartao_tabajara in resposta_cartao_valida):

  #Estrutura de decisão do cálculo do preço da carne Filé Duplo.
  if(quilos <= 5 and (tipo_carne == 'F' or tipo_carne == 'f')):

    preco_final = (4.90 * quilos)
    nome_carne = 'Filé Duplo'

  elif(quilos > 5 and (tipo_carne == 'F' or tipo_carne == 'f')):

    preco_final = (5.80 * quilos)
    nome_carne = 'Filé Duplo'

  #Estrutura de decisão do cálculo do preço da carne Alcatra.
  elif(quilos <= 5 and (tipo_carne == 'A' or tipo_carne == 'a')):

    preco_final = (5.90 * quilos)
    nome_carne = 'Alcatra'

  elif(quilos > 5 and (tipo_carne == 'A' or tipo_carne == 'a')):

    preco_final = (6.80 * quilos)
    nome_carne = 'Alcatra'

  #Estrutura de decisão do cálculo do preço da carne Picanha.
  elif(quilos <= 5 and (tipo_carne == 'P' or tipo_carne == 'p')):

    preco_final = (6.90 * quilos)
    nome_carne = 'Picanha'

  elif(quilos > 5 and (tipo_carne == 'P' or tipo_carne == 'p')):

    preco_final = (7.80 * quilos)
    nome_carne = 'Picanha'

  #Estrutura de decisão para aplicar o desconto caso o cartão tabajara seja usado.
  if(cartao_tabajara == 'S' or cartao_tabajara == 's'):

    desconto = (preco_final * 0.05)
    preco_final = (preco_final - desconto)
    forma_pagamento = 'Cartão Tabajara'

  print(f"Tipo de Carne: {nome_carne}")
  print(f"Quantidade em quilos: {quilos:.2f}kg")
  print(f"Forma de pagamento: {forma_pagamento}")
  print(f"Valor de desconto: R${desconto:.2f}")
  print(f"Preço Final: R${preco_final:.2f}")
